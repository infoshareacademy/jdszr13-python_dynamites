# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_csv('C:\\VSC_workspace\\projekt_I\\all_seasons.csv', index_col='Unnamed: 0')
dataset.set_axis(['Name', 'Team', 'Age','Height',"Weight", 'Collage', 'Country','Draft_Year', 'Draft_round' , 'Draft_number', "Games", 'Points', 'Rebound','Assist',"Rating", 'Rebound_offensive_[%]', 'Rebound_defensive_[%]','Usage',"Shooting efficiency", 'Teamate efficiency', 'Seasson'], axis='columns', inplace=True)
dataset
# Out:
#                     Name Team   Age  Height      Weight  \
# 0          Dennis Rodman  CHI  36.0  198.12   99.790240
# 1      Dwayne Schintzius  LAC  28.0  215.90  117.933920
# 2           Earl Cureton  TOR  39.0  205.74   95.254320
# 3            Ed O'Bannon  DAL  24.0  203.20  100.697424
# 4            Ed Pinckney  MIA  34.0  205.74  108.862080
# ...                  ...  ...   ...     ...         ...
# 12300    Markieff Morris  MIA  32.0  205.74  111.130040
# 12301     Markelle Fultz  ORL  24.0  193.04   94.800728
# 12302       Marcus Smart  BOS  28.0  193.04   99.790240
# 12303     Marcus Garrett  MIA  23.0  195.58   92.986360
# 12304       Micah Potter  DET  24.0  208.28  112.490816
#
#                            Collage Country Draft_Year Draft_round  \
# 0      Southeastern Oklahoma State     USA       1986           2
# 1                          Florida     USA       1990           1
# 2                    Detroit Mercy     USA       1979           3
# ...

# %%
scatter_plot = dataset.plot.scatter(x='Height', y='Weight',color='purple',figsize=(10,10))

# %%
scatter_plot = dataset.plot.scatter(x='Assist', y='Points',color='purple',figsize=(10,10))

# %%
scatter_plot = dataset.plot.scatter(x='Assist', y='Teamate efficiency',color='purple',figsize=(10,10))

# %%
scatter_plot = dataset.plot.scatter(x='Weight', y='Rebound',color='purple',figsize=(10,10))

# %%
scatter_plot = dataset.plot.scatter(x='Height', y='Rebound',color='purple',figsize=(10,10))

# %%
scatter_plot = dataset.plot.scatter(x='Weight', y='Rebound',color='purple',figsize=(10,10))
