# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
df = pd.read_csv('all_energy_statistics.csv')
# Out:
#   country_or_area               commodity_transaction  year  \
# 0         Austria  Additives and Oxygenates - Exports  1996
# 1         Austria  Additives and Oxygenates - Exports  1995
# 2         Belgium  Additives and Oxygenates - Exports  2014
# 3         Belgium  Additives and Oxygenates - Exports  2013
# 4         Belgium  Additives and Oxygenates - Exports  2012
# 5         Belgium  Additives and Oxygenates - Exports  2011
# 6         Belgium  Additives and Oxygenates - Exports  2010
# 7         Belgium  Additives and Oxygenates - Exports  2009
# 8         Czechia  Additives and Oxygenates - Exports  1998
# 9         Czechia  Additives and Oxygenates - Exports  1995
#
#                      unit  quantity  quantity_footnotes  \
# 0  Metric tons,  thousand       5.0                 NaN
# 1  Metric tons,  thousand      17.0                 NaN
# 2  Metric tons,  thousand       0.0                 NaN
# 3  Metric tons,  thousand       0.0                 NaN
# ...

# %%
df.head(10)
# Out:
#   country_or_area               commodity_transaction  year  \
# 0         Austria  Additives and Oxygenates - Exports  1996
# 1         Austria  Additives and Oxygenates - Exports  1995
# 2         Belgium  Additives and Oxygenates - Exports  2014
# 3         Belgium  Additives and Oxygenates - Exports  2013
# 4         Belgium  Additives and Oxygenates - Exports  2012
# 5         Belgium  Additives and Oxygenates - Exports  2011
# 6         Belgium  Additives and Oxygenates - Exports  2010
# 7         Belgium  Additives and Oxygenates - Exports  2009
# 8         Czechia  Additives and Oxygenates - Exports  1998
# 9         Czechia  Additives and Oxygenates - Exports  1995
#
#                      unit  quantity  quantity_footnotes  \
# 0  Metric tons,  thousand       5.0                 NaN
# 1  Metric tons,  thousand      17.0                 NaN
# 2  Metric tons,  thousand       0.0                 NaN
# 3  Metric tons,  thousand       0.0                 NaN
# ...

# %%
df.sample(20)
# Out:
#                 country_or_area  \
# 785117                 Portugal
# 876777       Russian Federation
# 61933             USSR (former)
# 74163                   Georgia
# 206392              Switzerland
# 910479            Guinea-Bissau
# 1075572                 Tunisia
# 1059347                 Ireland
# 653661               Seychelles
# 212378           Sudan (former)
# 718971                     Cuba
# 90789                   Austria
# 820805               Bangladesh
# 898776   Iran (Islamic Rep. of)
# 61013                     India
# 143144                 Cameroon
# 1185834                  Norway
# 594247                    Ghana
# 342408        Brunei Darussalam
# 441920          St. Kitts-Nevis
#
#                                      commodity_transaction  year  \
# 785117   Natural Gas (including LNG) - consumption by c...  2006
# 876777   Other bituminous coal - own use by electricity...  1994
# 61933                                    Bitumen - Exports  1991
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1189482 entries, 0 to 1189481
# Data columns (total 7 columns):
# country_or_area          1189482 non-null object
# commodity_transaction    1189482 non-null object
# year                     1189482 non-null int64
# unit                     1189482 non-null object
# quantity                 1189482 non-null float64
# quantity_footnotes       163946 non-null float64
# category                 1189482 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 63.5+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                year      quantity  quantity_footnotes
# count  1.189482e+06  1.189482e+06            163946.0
# mean   2.002852e+03  1.842648e+05                 1.0
# std    7.167345e+00  1.585663e+07                 0.0
# min    1.990000e+03 -8.643480e+05                 1.0
# 25%    1.997000e+03  1.400000e+01                 1.0
# 50%    2.003000e+03  1.890000e+02                 1.0
# 75%    2.009000e+03  2.265000e+03                 1.0
# max    2.014000e+03  6.680329e+09                 1.0

# %%
df.shape
# Out:
# (1189482, 7)

# %%
### Czyszczenie danych

# %%
df_clean = df.copy()
