# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('C:\\VSC_workspace\\projekt_I\\all_seasons.csv', index_col='Unnamed: 0')
dataset.set_axis(['Name', 'Team', 'Age','Height',"Weight", 'Collage', 'Country','Draft_Year', 'Draft_round' , 'Draft_number', "Games", 'Points', 'Zbiorki','Assist',"Rating", 'Rebound_offensive_[%]', 'Rebound_defensive_[%]','Usage',"Shooting efficiency", 'Teamate efficiency"', 'Seasson'], axis='columns', inplace=True)
dataset
# Out:
#                     Name Team   Age  Height      Weight  \
# 0          Dennis Rodman  CHI  36.0  198.12   99.790240
# 1      Dwayne Schintzius  LAC  28.0  215.90  117.933920
# 2           Earl Cureton  TOR  39.0  205.74   95.254320
# 3            Ed O'Bannon  DAL  24.0  203.20  100.697424
# 4            Ed Pinckney  MIA  34.0  205.74  108.862080
# ...                  ...  ...   ...     ...         ...
# 12300    Markieff Morris  MIA  32.0  205.74  111.130040
# 12301     Markelle Fultz  ORL  24.0  193.04   94.800728
# 12302       Marcus Smart  BOS  28.0  193.04   99.790240
# 12303     Marcus Garrett  MIA  23.0  195.58   92.986360
# 12304       Micah Potter  DET  24.0  208.28  112.490816
#
#                            Collage Country Draft_Year Draft_round  \
# 0      Southeastern Oklahoma State     USA       1986           2
# 1                          Florida     USA       1990           1
# 2                    Detroit Mercy     USA       1979           3
# ...

# %%
dataset.describe()
# Out:
#                 Age        Height        Weight         Games        Points  \
# count  12305.000000  12305.000000  12305.000000  12305.000000  12305.000000
# mean      27.084518    200.611602    100.369926     51.290532      8.172775
# std        4.335868      9.146321     12.477150     25.095909      5.974957
# min       18.000000    160.020000     60.327736      1.000000      0.000000
# 25%       24.000000    193.040000     90.718400     31.000000      3.600000
# 50%       26.000000    200.660000     99.790240     57.000000      6.700000
# 75%       30.000000    208.280000    108.862080     73.000000     11.500000
# max       44.000000    231.140000    163.293120     85.000000     36.100000
#
#             Zbiorki        Assist        Rating  Rebound_offensive_[%]  \
# count  12305.000000  12305.000000  12305.000000           12305.000000
# mean       3.559155      1.813986     -2.255733               0.054473
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12305 entries, 0 to 12304
# Data columns (total 21 columns):
# Name                     12305 non-null object
# Team                     12305 non-null object
# Age                      12305 non-null float64
# Height                   12305 non-null float64
# Weight                   12305 non-null float64
# Collage                  12305 non-null object
# Country                  12305 non-null object
# Draft_Year               12305 non-null object
# Draft_round              12305 non-null object
# Draft_number             12305 non-null object
# Games                    12305 non-null int64
# Points                   12305 non-null float64
# Zbiorki                  12305 non-null float64
# Assist                   12305 non-null float64
# Rating                   12305 non-null float64
# Rebound_offensive_[%]    12305 non-null float64
# Rebound_defensive_[%]    12305 non-null float64
# ...

# %%
dataset.isnull().sum()
# Out:
# Name                     0
# Team                     0
# Age                      0
# Height                   0
# Weight                   0
# Collage                  0
# Country                  0
# Draft_Year               0
# Draft_round              0
# Draft_number             0
# Games                    0
# Points                   0
# Zbiorki                  0
# Assist                   0
# Rating                   0
# Rebound_offensive_[%]    0
# Rebound_defensive_[%]    0
# Usage                    0
# Shooting efficiency      0
# Teamate efficiency"      0
# Seasson                  0
# dtype: int64

# %%
plt.figure(figsize=(16,16))

corr = dataset.corr()
corr = corr[abs(corr) > 0.5]

sns.heatmap(corr, cmap = 'RdBu', vmin=-1, vmax=1 , annot = True, cbar = False ,square = True, annot_kws = {
    'fontsize' : 16,
    'fontweight' : 'bold',
    'verticalalignment':'center'
}, 
)
